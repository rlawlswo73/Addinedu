# %% [markdown]
# <h1>2024.08.26.</h1>

# %%
from bs4 import BeautifulSoup

# %%
page = open("test.html").read()
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code By PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happly PinkWink.
#     <a href="https://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text first-item" id="three">
#     Happly Data Science.
#     <a href="https://www.python.org" id="pw-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <div>
#    <p class="outer-text first-item" id="second">
#     <b>
#      Data science is funny.
#     </b>
#    </p>
#    <p class="outer-text">
#     <b>
#      All I need is Love
#     </b>
#    </p>
#   </div>
#  </body>
# </html>

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code By PinkWink</title>
# </head>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happly PinkWink.
#                 <a href="https://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text first-item" id="three">
#                 Happly Data Science.
#                 <a href="https://www.python.org" id="pw-link">Python</a>
# </p>
# </div>
# <div>
# <p class="outer-text first-item" id="second">
# <b>Data science is funny.</b>
# </p>
# <p class="outer-text">
# <b>All I need is Love</b>
# </p>
# </div>
# </body>

# %%
soup.find("p")
# Out:
# <p class="inner-text first-item" id="first">
#                 Happly PinkWink.
#                 <a href="https://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all("p")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happly PinkWink.
#                  <a href="https://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text first-item" id="three">
#                  Happly Data Science.
#                  <a href="https://www.python.org" id="pw-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>Data science is funny.</b>
#  </p>,
#  <p class="outer-text">
#  <b>All I need is Love</b>
#  </p>]

# %%
soup.find_all(class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>Data science is funny.</b>
#  </p>,
#  <p class="outer-text">
#  <b>All I need is Love</b>
#  </p>]

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happly PinkWink.
#                  <a href="https://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
for tag in soup.find_all("p"):
    print("-----------")
    print(tag.get_text())
# Out:
# -----------
#
#                 Happly PinkWink.
#                 PinkWink
#
# -----------
#
#                 Happly Data Science.
#                 Python
#
# -----------
#
# Data science is funny.
#
# -----------
#
# All I need is Love

# %%
link_list = soup.find_all("a")
link_list
# Out:
# [<a href="https://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="pw-link">Python</a>]

# %%
for each in link_list:
    href = each["href"]
    text = each.string
    print(text + " -> " + href)
# Out:
# PinkWink -> https://www.pinkwink.kr
# Python -> https://www.python.org

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240821182425/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240821182425/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all("span", "value")[0].string
# Out:
# '1,331.40'

# %%
import urllib
from urllib.request import Request

url = "https://ko.wikipedia.org/wiki/{search_words}"
req = Request(url.format(search_words = urllib.parse.quote("구미호뎐 1938")))
res = urlopen(req)

soup = BeautifulSoup(res, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    구미호뎐 1938 - 위키백과, 우리 모두의 백과사전
#   </title>
#   <script>
# ...

# %%
for idx, each in enumerate(soup.find_all("ul")):
    print("[" + str(idx) + "]" + "======================")
    print(each.prettify())
# Out:
# [0]======================
# <ul class="vector-menu-content-list">
#  <li class="mw-list-item" id="n-mainpage-description">
#   <a accesskey="z" href="/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EB%8C%80%EB%AC%B8" title="대문으로 가기 [z]">
#    <span>
#     대문
#    </span>
#   </a>
#  </li>
#  <li class="mw-list-item" id="n-recentchanges">
#   <a accesskey="r" href="/wiki/%ED%8A%B9%EC%88%98:%EC%B5%9C%EA%B7%BC%EB%B0%94%EB%80%9C" title="위키의 최근 바뀐 목록 [r]">
#    <span>
#     최근 바뀜
#    </span>
#   </a>
#  </li>
#  <li class="mw-list-item" id="n-currentevents">
#   <a href="/wiki/%ED%8F%AC%ED%84%B8:%EC%9A%94%EC%A6%98_%ED%99%94%EC%A0%9C" title="최근의 소식 알아 보기">
#    <span>
#     요즘 화제
#    </span>
#   </a>
#  </li>
#  <li class="mw-list-item" id="n-randompage">
#   <a accesskey="x" href="/wiki/%ED%8A%B9%EC%88%98:%EC%9E%84%EC%9D%98%EB%AC%B8%EC%84%9C" title="무작위로 선택된 문서 불러오기 [x]">
#    <span>
#     임의의 문서로
#    </span>
#   </a>
#  </li>
#  <li class="mw-list-item" id="n-sitesupport">
# ...

# %%
soup.find_all("ul")[10]
# Out:
# <ul class="vector-toc-list" id="toc-기획_의도-sublist">
# </ul>

# %%
soup.find_all("ul")[60]
# Out:
# <ul><li><a href="/wiki/%EC%98%81%ED%9B%88_(1997%EB%85%84)" title="영훈 (1997년)">김영훈</a> : 삼천갑자 동방삭 역 (†) (1회)</li>
# <li><a href="/wiki/%ED%99%A9%EC%84%9D%EC%A0%95" title="황석정">황석정</a> : 최승자 역 (2회)</li>
# <li><a href="/wiki/%EC%95%88%EC%9E%AC%EB%AA%A8" title="안재모">안재모</a> : 야인시대 김두한 역 (7회)</li>
# <li><a href="/wiki/%EA%B9%80%EB%B2%95%EB%9E%98" title="김법래">김법래</a> : 독각귀 역 (8회)</li>
# <li><a href="/wiki/%EC%A1%B0%EB%B3%B4%EC%95%84" title="조보아">조보아</a> : 남지아 / 이아음 역 (12회)</li></ul>

# %%
list = []

ul = soup.find_all("ul")[60]
for a in ul.find_all("a"):
    list.append(a.string)

list
# Out:
# ['김영훈', '황석정', '안재모', '김법래', '조보아']

# %% [markdown]
# <h3>고민해보기</h3>

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={search_words}"
# # url = "https://search.naver.com/search.naver?&query={search_words}"
# req = Request(url.format(search_words = urllib.parse.quote("영화순위")))
# res = urlopen(req)

# soup = BeautifulSoup(res, "html.parser")

# %%
#ul = soup.find_all("ul", "_panel")
#print(ul)
# for idx, each in enumerate(soup.find_all("span", "sub_text")):
#     print("[" + str(idx) + "]" + "-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-|")

#     print(each.get_text())

# %%
# list = []

# ul = soup.find_all("ul")[2]
# for s in ul.find_all("span", "sub_text"):
#     list.append(s)
#     #print("[" + str(idx) + "] : " ,s)
# list

# %% [markdown]
# <h3>다시 수업 진행</h3>

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

import urllib
from urllib.request import Request

from user_agent import generate_user_agent

#response = request.get(url, headers={'User-agent':'Mozila/5.0'})

# %%
# url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={search_words}"
url = "https://search.naver.com/search.naver?&query={search_word1}+{search_word2}"
req = Request(url.format(search_word1 = urllib.parse.quote("박스오피스"),
                         search_word2 = urllib.parse.quote("평점순")))

# headers = {'User-Agent':'Mozilla/5.0'}

# url = "/home/addinedu/dev_ws/EDA/data/output.html"
# page = open("test.html").read()
# soup = BeautifulSoup(page, "html.parser")

res = urlopen(req)

soup = BeautifulSoup(res, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer"/>
#   <meta content="telephone=no,address=no,email=no" name="format-detection"/>
#   <meta content="박스오피스 평점순 : 네이버 검색" property="og:title">
#    <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/>
#    <meta content="'박스오피스 평점순'의 네이버 검색 결과입니다." property="og:description"/>
#    <meta content="'박스오피스 평점순'의 네이버 검색 결과입니다." lang="ko" name="description"/>
#    <title>
#     박스오피스 평점순 : 네이버 검색
#    </title>
#    <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/>
#    <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml">
#     <script>
#      if (top.frames.length!=0 || window!=top) window.open(location, "_top");
#     </script>
# ...

# %%
movie_panel = soup.find_all(class_="_panel")
movie_panel
# Out:
# [<ul class="_panel"> <li> <a class="inner" href="?where=nexearch&amp;sm=tab_etc&amp;mra=bkEw&amp;pkid=68&amp;os=33799832&amp;qvt=0&amp;query=%EC%97%90%EC%9D%B4%EB%A6%AC%EC%96%B8%3A%20%EB%A1%9C%EB%AC%BC%EB%A3%A8%EC%8A%A4" nocr="" onclick="return goOtherCR(this, 'a=nco_x0a*M.boxschinfo&amp;r=1&amp;i=1800009D_000000000000&amp;u=' + urlencode(this.href));"> <div class="item"> <div class="thumb"> <span class="cm_thumb_rank_number"><span class="this_bg"></span><span class="this_text">1</span></span> <img alt="에이리언: 로물루스" height="145" onerror="this.src='https://ssl.pstatic.net/sstatic/keypage/outside/scui/weboriginal_new/im/no_img.png'" src="https://search.pstatic.net/common?type=f&amp;size=206x290&amp;quality=100&amp;direct=true&amp;src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20240814_274%2F1723626467288x02BG_JPEG%2Fmovie_image.jpg" width="103"/> </div> <div class="title_box"> <strong class="name">에이리언: 로물루스</strong> <span class="sub_text">3.9만명</span> </div> </div> </a> </li> <li> <a 
# ...

# %%
rating = soup.find(class_="_panel_rating _tab_content")
for each in rating.find_all("li"):
    print(each.prettify())
# Out:
# <li>
#  <a class="inner" href="?where=nexearch&amp;sm=tab_etc&amp;mra=bkEw&amp;pkid=68&amp;os=32848283&amp;qvt=0&amp;query=1923%20%EA%B0%84%ED%86%A0%EB%8C%80%ED%95%99%EC%82%B4" nocr="" onclick="return goOtherCR(this, 'a=nco_x0a*M.boxschinfo&amp;r=1&amp;i=1800009D_000000000000&amp;u=' + urlencode(this.href));">
#   <div class="item">
#    <div class="thumb">
#     <span class="cm_thumb_rank_number">
#      <span class="this_bg">
#      </span>
#      <span class="this_text">
#       1
#      </span>
#     </span>
#     <img alt="1923 간토대학살" height="145" onerror="this.src='https://ssl.pstatic.net/sstatic/keypage/outside/scui/weboriginal_new/im/no_img.png'" src="https://search.pstatic.net/common?type=f&amp;size=206x290&amp;quality=100&amp;direct=true&amp;src=https%3A%2F%2Fs.pstatic.net%2Fmovie.phinf%2F20240827_264%2F17247232977378sc0f_PNG%2Fmovie_image.jpg" width="103"/>
#    </div>
#    <div class="title_box">
#     <strong class="name">
#      1923 간토대학살
#     </strong>
# ...

# %%
rating = soup.find(class_="_panel_rating _tab_content")
for idx, each in enumerate(rating.find_all("li")):
    print("[" + str(idx) + "]")
    print("title : " + each.find("strong", class_="name").string)
# Out:
# [0]
# title : 1923 간토대학살
# [1]
# title : 세븐틴 투어 ‘팔로우’ 어게...
# [2]
# title : 비포 선셋
# [3]
# title : 인사이드 아웃 2
# [4]
# title : 호밀밭의 반항아
# [5]
# title : 에이리언: 로물루스
# [6]
# title : 사랑의 하츄핑
# [7]
# title : 퍼펙트 데이즈
# [8]
# title : 극장총집편 봇치 더 록! 전편
# [9]
# title : 트위스터스
# [10]
# title : 빅토리
# [11]
# title : 희생
# [12]
# title : 명탐정 코난: 100만 달러...
# [13]
# title : 10 라이브즈
# [14]
# title : 파일럿
# [15]
# title : 행복의 나라
# [16]
# title : 데드풀과 울버린
# [17]
# title : 슈퍼배드 4
# [18]
# title : 극장판 블루 록 -에피소드 ...
# [19]
# title : 필사의 추격
# [20]
# title : 프로이트의 라스트 세션
# [21]
# title : 늘봄가든

# %%
ratng = soup.find(class_="_panel_rating _tab_content")
for idx, each in enumerate(rating.find_all("li")):
    print("[" + str(idx) + "]")
    print("title : " + each.find("strong", class_="name").string)
    print("rating : " + each.find("span", class_="sub_text").get_text())
# Out:
# [0]
# title : 1923 간토대학살
# rating : 9.91
# [1]
# title : 세븐틴 투어 ‘팔로우’ 어게...
# rating : 9.35
# [2]
# title : 비포 선셋
# rating : 9.01
# [3]
# title : 인사이드 아웃 2
# rating : 8.94
# [4]
# title : 호밀밭의 반항아
# rating : 8.82
# [5]
# title : 에이리언: 로물루스
# rating : 8.80
# [6]
# title : 사랑의 하츄핑
# rating : 8.75
# [7]
# title : 퍼펙트 데이즈
# rating : 8.72
# [8]
# title : 극장총집편 봇치 더 록! 전편
# rating : 8.49
# [9]
# title : 트위스터스
# rating : 8.34
# [10]
# title : 빅토리
# rating : 8.21
# [11]
# title : 희생
# rating : 8.16
# [12]
# title : 명탐정 코난: 100만 달러...
# rating : 8.05
# [13]
# title : 10 라이브즈
# rating : 7.90
# [14]
# title : 파일럿
# rating : 7.75
# [15]
# title : 행복의 나라
# rating : 7.74
# [16]
# title : 데드풀과 울버린
# rating : 7.70
# [17]
# title : 슈퍼배드 4
# rating : 7.43
# [18]
# title : 극장판 블루 록 -에피소드 ...
# rating : 7.39
# [19]
# title : 필사의 추격
# rating : 7.28
# [20]
# title : 프로이트의 라스트 세션
# rating : 6.72
# [21]
# title : 늘봄가든
# rating : 5.79

# %%
prefix = "https://search.naver.com/search.naver"

rating = soup.find(class_="_panel_rating _tab_content")
for idx, each in enumerate(rating.find_all("li")):
    print("[" + str(idx) + "]")
    print("title : " + each.find("strong", class_="name").string)
    print("rating : " + each.find("span", class_="sub_text").get_text())
    print("link : " + prefix + each.find("a")["href"])
# Out:
# [0]
# title : 1923 간토대학살
# rating : 9.91
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32848283&qvt=0&query=1923%20%EA%B0%84%ED%86%A0%EB%8C%80%ED%95%99%EC%82%B4
# [1]
# title : 세븐틴 투어 ‘팔로우’ 어게...
# rating : 9.35
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=34429371&qvt=0&query=%EC%84%B8%EB%B8%90%ED%8B%B4%20%ED%88%AC%EC%96%B4%20%E2%80%98%ED%8C%94%EB%A1%9C%EC%9A%B0%E2%80%99%20%EC%96%B4%EA%B2%8C%EC%9D%B8%20%ED%88%AC%20%EC%8B%9C%EB%84%A4%EB%A7%88
# [2]
# title : 비포 선셋
# rating : 9.01
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1776940&qvt=0&query=%EB%B9%84%ED%8F%AC%20%EC%84%A0%EC%85%8B
# [3]
# title : 인사이드 아웃 2
# rating : 8.94
# link : https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32619620&qvt=0&query=%EC%9D%B8%EC%82%AC%EC%9D%B4%EB%93%9C%20%EC%95%84%EC%9B%83%202
# [4]
# title : 호밀밭의 반항아
# rating : 8.82
# ...

# %%
prefix = "https://search.naver.com/search.naver"

movie_list = []

rating = soup.find(class_="_panel_rating _tab_content")
for idx, each in enumerate(rating.find_all("li")):
    movie = []
    movie.append(each.find("strong", class_="name").string)
    movie.append(each.find("span", class_="sub_text").get_text())
    movie.append(prefix + each.find("a")["href"])

    movie_list.append(movie)

movie_list
# Out:
# [['1923 간토대학살',
#   '9.91',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32848283&qvt=0&query=1923%20%EA%B0%84%ED%86%A0%EB%8C%80%ED%95%99%EC%82%B4'],
#  ['세븐틴 투어 ‘팔로우’ 어게...',
#   '9.35',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=34429371&qvt=0&query=%EC%84%B8%EB%B8%90%ED%8B%B4%20%ED%88%AC%EC%96%B4%20%E2%80%98%ED%8C%94%EB%A1%9C%EC%9A%B0%E2%80%99%20%EC%96%B4%EA%B2%8C%EC%9D%B8%20%ED%88%AC%20%EC%8B%9C%EB%84%A4%EB%A7%88'],
#  ['비포 선셋',
#   '9.01',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1776940&qvt=0&query=%EB%B9%84%ED%8F%AC%20%EC%84%A0%EC%85%8B'],
#  ['인사이드 아웃 2',
#   '8.94',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32619620&qvt=0&query=%EC%9D%B8%EC%82%AC%EC%9D%B4%EB%93%9C%20%EC%95%84%EC%9B%83%202'],
#  ['호밀밭의 반항아',
#   '8.82',
# ...

# %%
res = urlopen(movie_list[13][2])
soup = BeautifulSoup(res, "html.parser")
print(soup.find("strong", class_="_text").string)
# Out:
# 10 라이브즈

# %%
# def get_title(url):
#     res = urlopen(url)
#     soup = BeautifulSoup(res, "html.parser")
#     return soup.find("strong", class_="_text").string

def get_title(url):
    req = Request(url=url, headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, 'html.parser')
    tag = soup.find('strong', class_='_text')
    return tag.string

# %%
get_title(movie_list[13][2])
# Out:
# '10 라이브즈'

# %%
import time

for movie in movie_list:
    movie[0] = get_title(movie[2])
    time.sleep(0.5)

movie_list
# Out:
# [['1923 간토대학살',
#   '9.91',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32848283&qvt=0&query=1923%20%EA%B0%84%ED%86%A0%EB%8C%80%ED%95%99%EC%82%B4'],
#  ['세븐틴 투어 ‘팔로우’ 어게인 투 시네마',
#   '9.35',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=34429371&qvt=0&query=%EC%84%B8%EB%B8%90%ED%8B%B4%20%ED%88%AC%EC%96%B4%20%E2%80%98%ED%8C%94%EB%A1%9C%EC%9A%B0%E2%80%99%20%EC%96%B4%EA%B2%8C%EC%9D%B8%20%ED%88%AC%20%EC%8B%9C%EB%84%A4%EB%A7%88'],
#  ['비포 선셋',
#   '9.01',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=1776940&qvt=0&query=%EB%B9%84%ED%8F%AC%20%EC%84%A0%EC%85%8B'],
#  ['인사이드 아웃 2',
#   '8.94',
#   'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bkEw&pkid=68&os=32619620&qvt=0&query=%EC%9D%B8%EC%82%AC%EC%9D%B4%EB%93%9C%20%EC%95%84%EC%9B%83%202'],
#  ['호밀밭의 반항아',
#   '8.82',
# ...

# %%
import pandas as pd

df = pd.DataFrame(movie_list, columns=["name","rating","link"])
df
# Out:
#                       name rating  \
# 0               1923 간토대학살   9.91
# 1   세븐틴 투어 ‘팔로우’ 어게인 투 시네마   9.35
# 2                    비포 선셋   9.01
# 3                인사이드 아웃 2   8.94
# 4                 호밀밭의 반항아   8.82
# 5               에이리언: 로물루스   8.80
# 6                  사랑의 하츄핑   8.75
# 7                  퍼펙트 데이즈   8.72
# 8         극장총집편 봇치 더 록! 전편   8.49
# 9                    트위스터스   8.34
# 10                     빅토리   8.21
# 11                      희생   8.16
# 12   명탐정 코난: 100만 달러의 펜타그램   8.05
# 13                 10 라이브즈   7.90
# 14                     파일럿   7.75
# 15                  행복의 나라   7.74
# 16                데드풀과 울버린   7.70
# 17                  슈퍼배드 4   7.43
# 18      극장판 블루 록 -에피소드 나기-   7.39
# 19                  필사의 추격   7.28
# 20            프로이트의 라스트 세션   6.72
# 21                    늘봄가든   5.79
#
#                                                  link
# 0   https://search.naver.com/search.naver?where=ne...
# ...

# %% [markdown]
# <h1>2024.08.27</h1>

# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
from urllib.request import urlopen
from urllib.request import Request
from user_agent import generate_user_agent

url = 'https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/'

req = Request(url=url, headers={'User-Agent':generate_user_agent()})
page = urlopen(req)
soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     The 50 Best Sandwiches in Chicago – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# ...

# %%
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
print(soup.find_all('div', 'sammy')[0].prettify())
# Out:
# <div class="sammy" style="position: relative;">
#  <div class="sammyRank">
#   1
#  </div>
#  <div class="sammyListing">
#   <a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/">
#    <b>
#     BLT
#    </b>
#    <br/>
#    Old Oak Tap
#    <br/>
#    <em>
#     Read more
#    </em>
#   </a>
#  </div>
# </div>

# %%
item = soup.find_all('div', 'sammy')[0]
item.find(class_="sammyRank").string
# Out:
# '1'

# %%
item.find('b').string, item.find('br').string
# Out:
# ('BLT', None)

# %%
item.find(class_="sammyListing").get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
import re

text_list = re.split(('\n'), item.find(class_="sammyListing").get_text())

print(text_list[0])
print(text_list[1])
# Out:
# BLT
# Old Oak Tap

# %%
item.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
prefix = "https://www.chicagomag.com"
print(prefix + item.find('a')['href'])
# Out:
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/

# %%
for item in soup.find_all('div', 'sammy'):
    print(item.find('a')['href'])
# Out:
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Acadia-Lobster-Roll/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Birchwood-Kitchen-Smoked-Salmon-Salad/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Cemitas-Puebla-Atomica-Cemitas/
# /Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Nana-Grilled-Laughing-Bird-Shrimp-and-Fried-Oyster-Po-Boy/
# ...

# %%
from urllib.parse import urljoin

for item in soup.find_all('div', 'sammy'):
    print(urljoin("https://www.chicagomag.com", item.find('a')['href']))
# Out:
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Acadia-Lobster-Roll/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Birchwood-Kitchen-Smoked-Salmon-Salad/
# ...

# %%
from urllib.parse import urljoin

rank_list = []
menu_list = []
cafe_list = []
link_list = []

for item in soup.find_all('div','sammy'):
    rank_list.append(item.find(class_='sammyRank').string)

    text_list = re.split(('\n'), item.find(class_="sammyListing").get_text())
    menu_list.append(text_list[0])
    cafe_list.append(text_list[1])

    link_list.append(urljoin("https://www.chicagomag.com", item.find('a')['href']))

# %%
for i in range(5):
    print(rank_list[i] + ". " + menu_list[i] + " - " + cafe_list[i] + " " + link_list[i])
# Out:
# 1. BLT - Old Oak Tap https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# 2. Fried Bologna - Au Cheval https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# 3. Woodland Mushroom - Xoco https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/
# 4. Roast Beef - Al’s Deli https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/
# 5. PB&L - Publican Quality Meats https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/

# %%
len(rank_list), len(menu_list), len(cafe_list), len(link_list)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data = {'Rank':rank_list, 'Menu':menu_list, 'Cafe':cafe_list, 'URL':link_list}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df = pd.DataFrame(data, columns=['Rank', 'Cafe', 'Menu', 'URL'])
df.head(5)
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df.to_csv("../data/chicago_sandwich.csv", sep=",", encoding="utf-8")

# %%
req = Request(url=df['URL'][0], headers={'User-Agent':generate_user_agent()})
page = urlopen(req)
soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     1. Old Oak Tap BLT – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# ...

# %%
print(soup.find('p', 'addy').get_text())
# Out:
# $10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com

# %%
import re

text = """Luke Skywarker 02-123-4567 luke@daum.net 
          다스베이더 010-9999-9999 darth_vader@gmail.com 서울시 서초구 서초동 서초아파트 
          princess leia 010 2454 3457 leia@gmail.com"""

# %%
re.search("\d+", text).group()
# Out:
# '02'

# %%
re.search("\d+-\d+-\d+", text).group()
# Out:
# '02-123-4567'

# %%
re.findall("\d+-\d+-\d+", text)
# Out:
# ['02-123-4567', '010-9999-9999']

# %%
re.findall("\w+@\w+.\w",text)
# Out:
# ['luke@daum.n', 'darth_vader@gmail.c', 'leia@gmail.c']

# %%
re.findall("[가-힣]+", text)
# Out:
# ['다스베이더', '서울시', '서초구', '서초동', '서초아파트']

# %%
re.findall("[가-힣]+시\s[가-힣]+구\s[가-힣]+동", text)
# Out:
# ['서울시 서초구 서초동']

# %%
re.search("[가-힣]+아파트", text).span()
# Out:
# (106, 111)

# %%
text[106:111]
# Out:
# '서초아파트'

# %%
print(soup.find('p', 'addy').get_text())
# Out:
# $10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com

# %%
import re

text = soup.find('em').get_text()
re.split(".,", text)
# Out:
# ['$10. 2109 W. Chicago Ave', ' 773-772-040', ' theoldoaktap.com']

# %%
re.split(".,", text)[0]
# Out:
# '$10. 2109 W. Chicago Ave'

# %%
text = re.split(".,", text)[0]
re.search("\$\d+.(\d+)?", text).group()
# Out:
# '$10.'

# %%
price = re.search("\$\d+.(\d+)?",text).group()
address = text[len(price) + 1:]
address
# Out:
# '2109 W. Chicago Ave'

# %%
# price_list = []
# address_list = []

# for idx in df.index[:3]:
#     req = Request(url=df['URL'][idx], headers={'User-Agent':generate_user_agent()})
#     page = urlopen(req)
#     soup = BeautifulSoup(page, "html.parser")

#     text = re.split('.,', soup.find('p', 'addy').get_text())[0]
#     price = re.search("\$\d+\.(\d+)?", text).group()
#     address = text[len(price) + 1:]

#     price_list.append(price)
#     address_list.append(address)

# price_list, address_list

# %%
# 올바른 예
price_list = []
address_list = []

# 컴퓨터 리소스 최소화
for idx, row in df[:3].iterrows():
    req = Request(url=row['URL'], headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, "html.parser")

    text = re.split('.,', soup.find('p', 'addy').get_text())[0]
    price = re.search("\$\d+\.(\d+)?", text).group()
    address = text[len(price) + 1:]

    price_list.append(price)
    address_list.append(address)

price_list, address_list
# Out:
# (['$10.', '$9.', '$9.50'],
#  [' 2109 W. Chicago Ave', ' 800 W. Randolph St', '. 445 N. Clark St'])

# %%
for item in df[:3]['URL']:
    print(item)
# 정석
# Out:
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/

# %%
for idx in df[:3].index:
    print(df['URL'][idx])
# Out:
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/

# %% [markdown]
# iterrows() 함수는 인자로 인덱스와 나머지 row 값을 받는다.

# %%
for idx, row in df[:3].iterrows():
    print(row['URL'])
# Out:
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/

# %%
from tqdm import tqdm

price_list = []
address_list = []

for idx, row in tqdm(df.iterrows(), total=len(df.index)):
    req = Request(url=row['URL'], headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    soup = BeautifulSoup(page, "html.parser")

    text = re.split('.,', soup.find('p', 'addy').get_text())[0]
    price = re.search('\$\d+\.(\d+)?', text).group()
    address = text[len(price) + 1:]

    price_list.append(price)
    address_list.append(address)
# Out:
# ...
# 100%|██████████| 50/50 [01:04<00:00,  1.28s/it]

# %%
len(price_list), len(address_list)
# Out:
# (50, 50)

# %%
df['Price'] = price_list
df['Address'] = address_list

df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price', 'Address']]
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price               Address
# Rank
# 1                Old Oak Tap                BLT   $10.   2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.    800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50     . 445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40        . 914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.     825 W. Fulton Mkt

# %%
df.to_csv("../data/chicago_sandwich2.csv", sep=",", encoding="utf-8")

# %%
import folium
folium.Map(location=[45.5234, -122.6750])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map(location=[45.5234, -122.6750], tiles="Cartodb positron", zoom_start=13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# folium.Map(location=[22.20111, 113.54417], tiles="Cartodb Positron", zoom_start=13)

# %%
my_map = folium.Map(loaction=[45.372, -121.6972], tiles="OpenStreetMap", zoom_start=12)

folium.Marker([45.3288, -121.6625], popup="<i>Mt. Hood Meadows</i>").add_to(my_map)
folium.Marker([45.3288, -121.7113], popup="<b>Timberline Lodge</b>").add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map = folium.Map(location=[45.372, -121.6972], tiles="OpenStreetMap", zoom_start=12)

folium.Marker(
    location=[45.3288, -121.6625],
    popup="Mt. Hood Meadows",
    icon=folium.Icon(icon="cloud")
).add_to(my_map)

folium.Marker(
    location=[45.3311, -121.7113],
    popup="Timverline Lodge",
    icon=folium.Icon(color="green")
).add_to(my_map)

folium.Marker(
    location=[45.3300, -121.6823],
    popup="한글 테스트",
    icon=folium.Icon(icon="info-sign", color="red")
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map = folium.Map(location=[45.5236, -122.66750], tiles="Cartodb Positron", zoom_start=13)

folium.Circle(
    radius=100,
    location=[45.5244, -122.6699],
    popup="The Waterfront",
    color='red', fill=False
).add_to(my_map)

folium.CircleMarker(
    radius=50,
    location=[45.5215, -122.6261],
    popup="Laurelhurst Part",
    color='#3186cc', 
    fill=True,
    fill_color = "#3186cc"
).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map = folium.Map(location=[46.1911, -122.1889], tiles="OpenStreetMap", zoom_start=13)

my_map.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import googlemaps

gmaps_key = "AIzaSyCdzl_R2adA5vbM-_lbZ_CcwSmzj8Jv800"
gmaps = googlemaps.Client(key=gmaps_key)

geocode = gmaps.geocode(address="1547 N. Wells St Chicago")
geocode
# Out:
# [{'address_components': [{'long_name': '1547',
#     'short_name': '1547',
#     'types': ['street_number']},
#    {'long_name': 'North Wells Street',
#     'short_name': 'N Wells St',
#     'types': ['route']},
#    {'long_name': 'Near North Side',
#     'short_name': 'Near North Side',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Chicago',
#     'short_name': 'Chicago',
#     'types': ['locality', 'political']},
#    {'long_name': 'Cook County',
#     'short_name': 'Cook County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Illinois',
#     'short_name': 'IL',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '60610', 'short_name': '60610', 'types': ['postal_code']}],
#   'formatted_address': '1547 N Wells St, Chicago, IL 60610, USA',
# ...

# %%
import json
print(json.dumps(geocode, indent=1))
# Out:
# [
#  {
#   "address_components": [
#    {
#     "long_name": "1547",
#     "short_name": "1547",
#     "types": [
#      "street_number"
#     ]
#    },
#    {
#     "long_name": "North Wells Street",
#     "short_name": "N Wells St",
#     "types": [
#      "route"
#     ]
#    },
#    {
#     "long_name": "Near North Side",
#     "short_name": "Near North Side",
#     "types": [
#      "neighborhood",
#      "political"
#     ]
#    },
#    {
#     "long_name": "Chicago",
#     "short_name": "Chicago",
#     "types": [
#      "locality",
#      "political"
#     ]
#    },
#    {
#     "long_name": "Cook County",
#     "short_name": "Cook County",
#     "types": [
#      "administrative_area_level_2",
#      "political"
#     ]
#    },
#    {
#     "long_name": "Illinois",
#     "short_name": "IL",
#     "types": [
#      "administrative_area_level_1",
#      "political"
#     ]
#    },
#    {
#     "long_name": "United States",
#     "short_name": "US",
#     "types": [
# ...

# %%
lat = geocode[0].get("geometry")["location"]["lat"]
lng = geocode[0].get("geometry")["location"]["lng"]

lat, lng
# Out:
# (41.9105258, -87.6343775)

# %%
import folium

df = pd.read_csv("../data/chicago_sandwich2.csv", sep=",", encoding="utf-8")
df.tail(10)
# Out:
#     Rank                         Cafe                                    Menu  \
# 40    41               Z&H MarketCafe                              The Marty
# 41    42   Market House on the Square                               Whitefish
# 42    43         Elaine’s Coffee Call  Oat Bread, Pecan Butter, and Fruit Jam
# 43    44  Marion Street Cheese Market                        Cauliflower Melt
# 44    45                     Cafecito                                  Cubana
# 45    46                     Chickpea                                   Kufta
# 46    47       The Goddess and Grocer                      Debbie’s Egg Salad
# 47    48                      Zenwich                              Beef Curry
# 48    49              Toni Patisserie                           Le Végétarien
# 49    50              Phoebe’s Bakery                              The Gatsby
#
#     Price                Address
# 40  $7.25      . 1323 E. 57th St
# 41   $11.         655 Forest Ave
# ...

# %%
for idx, row in df.iterrows():
    print(str(idx) + ".\t" + row["Address"])
# Out:
# 0.	 2109 W. Chicago Ave
# 1.	 800 W. Randolph St
# 2.	. 445 N. Clark St
# 3.	. 914 Noyes St
# 4.	 825 W. Fulton Mkt
# 5.	. 100 E. Walton St
# 6.	 1639 S. Wabash Ave
# 7.	 2211 W. North Ave
# 8.	 3619 W. North Ave
# 9.	 3267 S. Halsted St
# 10.	 2537 N. Kedzie Blvd
# 11.	. Multiple location
# 12.	 3124 N. Broadwa
# 13.	 3455 N. Southport Ave
# 14.	 2657 N. Kedzie Ave
# 15.	. 1120 W. Grand Ave
# 16.	. 1141 S. Jefferson St
# 17.	. 333 E. Benton Pl
# 18.	. 1411 N. Wells St
# 19.	 1747 N. Damen Ave
# 20.	 3209 W. Irving Park Rd
# 21.	 Multiple location
# 22.	 5347 N. Clark St
# 23.	. 2954 W. Irving Park Rd
# 24.	. Multiple location
# 25.	. 191 Skokie Valley Rd
# 26.	. Multiple location
# 27.	. 1818 W. Wilson Ave
# 28.	 2517 W. Division St
# 29.	 218 W. Kinzie St
# 30.	. Multiple location
# 31.	. 1547 N. Wells St
# 32.	 415 N. Milwaukee Ave
# 33.	. 1840 N. Damen Ave
# 34.	 1220 W. Webster Ave
# 35.	 5357 N. Ashland Ave
# 36.	 1834 W. Montrose Ave
# 37.	 615 N. State St
# ...

# %%
geocode = gmaps.geocode(address=".Multiple loction")
geocode
# Out:
# []

# %%
import numpy as np

lat_list = [] 
lng_list = []

for idx, row in tqdm(df.iterrows(), total=len(df.index)):
    geocode = gmaps.geocode(row["Address"] + ", Chicago")

    lat = geocode[0].get("geometry")["location"]["lat"] if len(geocode) > 0 else np.nan
    lng = geocode[0].get("geometry")["location"]["lng"] if len(geocode) > 0 else np.nan

    lat_list.append(lat)
    lng_list.append(lng)

len(lat_list) , len(lng_list)
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  5.95it/s]
# (50, 50)

# %%
df["lat"] = lat_list
df["lng"] = lng_list

df.head()
# Out:
#    Rank                    Cafe               Menu  Price  \
# 0     1             Old Oak Tap                BLT   $10.
# 1     2               Au Cheval      Fried Bologna    $9.
# 2     3                    Xoco  Woodland Mushroom  $9.50
# 3     4               Al’s Deli         Roast Beef  $9.40
# 4     5  Publican Quality Meats               PB&L   $10.
#
#                 Address        lat        lng
# 0   2109 W. Chicago Ave  41.895589 -87.679962
# 1    800 W. Randolph St  41.884639 -87.647590
# 2     . 445 N. Clark St  41.890523 -87.630783
# 3        . 914 Noyes St  42.058322 -87.683748
# 4     825 W. Fulton Mkt  41.886604 -87.648536

# %%
mapping = folium.Map(location=[lat_list[0], lng_list[0]], zoom_start=11)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for idx, row in df.iterrows():
    if row["lat"] == np.nan or row["lng"] == np.nan:
        continue
    else :
        folium.Marker(
            location=[row["lat"], row["lng"]], 
            popup=row["Cafe"],
            icon=folium.Icon(icon="home", color="blue")
        ).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
print(geocode[0].get("types"))
# Out:
# ['subpremise']

# %%
geocode[0].get("types")
# Out:
# ['subpremise']
