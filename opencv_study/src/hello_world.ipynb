# %% [markdown]
# <h1>2024.09.12.</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic = Image.open('../data/test.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x960>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (960, 540, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()
plt.imshow(pic_red[:,:,0])

# %%
pic_red = pic_arr.copy()
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
pic_red[:,:,1] = 0
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0
plt.imshow(pic_red)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../data/test.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
tmp = cv2.imread('./melonglong.jpg')
type(tmp)
# Out:
# [ WARN:0@112.810] global loadsave.cpp:241 findDecoder imread_('./melonglong.jpg'): can't open/read file: check file path/integrity
# NoneType

# %%
img.shape
# Out:
# (960, 540, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../data/test.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img.shape
# Out:
# (960, 540, 3)

# %%
new_img = cv2.resize(fix_img, (800, 600))
plt.imshow(new_img)

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %%
plt.imshow(cv2.flip(fix_img, -1))

# %%
plt.imshow(img_gray, cmap='gray')

# %%
cv2.imwrite('../data/test_gray.jpg', img_gray)
# Out:
# True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
blank_img = np.zeros((512, 512, 3), dtype=np.int16)
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(384, 0), pt2=(510, 150), color=(0,255,0), thickness=10)
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=20)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(blank_img)

# %%
cv2.line(blank_img, pt1=(0,0), pt2=(512,512), color=(102,255,255), thickness=5)
plt.imshow(blank_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img, text='Hello', org=(10, 500),
            fontFace=font, fontScale=4, color=(255,255,255),
            thickness=3, lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %%
blank_img = np.zeros((512,512,3), dtype=np.int32)
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))
pts.shape
# Out:
# (4, 1, 2)

# %%
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv2.polylines(blank_img, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(blank_img)

# %%
import numpy as np

img = np.full((400, 400, 3), 255, np.uint8)

cv2.line(img, (50, 50), (200, 50), (0,0,255), 5)
cv2.line(img, (50,60), (150, 160), (0,0,128))

plt.imshow(img)

# %%
cv2.rectangle(img, (50, 200, 150, 100), (0, 255, 0), 2)
cv2.rectangle(img, (70, 220), (180, 280), (0, 128, 0), -1)

plt.imshow(img)

# %%
cv2.circle(img, (300, 100), 30, (255,255,0), -1, cv2.LINE_AA)
cv2.circle(img, (300, 100), 60, (255,0,0), 3, cv2.LINE_AA)

pts = np.array([[255, 200], [300, 200], [350, 300], [250, 300]])
cv2.polylines(img, [pts], True, (255,0,255), 2)

plt.imshow(img)
